# %% [markdown]
# ## Setting up

# %% [markdown]
# ### Install Atorage

# %%
# !pip install azure-storage-blob
# !pip install boto3
# !pip install google-cloud-storage
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.20.0-py3-none-any.whl (392 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.2/392.2 kB 5.6 MB/s eta 0:00:00
# Collecting azure-core>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.7)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-storage-blob) (2024.2.2)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.20.0 isodate-0.6.1
# Collecting boto3
#   Downloading boto3-1.34.103-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 2.7 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.103 (from boto3)
#   Downloading botocore-1.34.103-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 46.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.103->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.103->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.103->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.34.103 botocore-1.34.103 jmespath-1.0.1 s3transfer-0.10.1
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.7.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (3.20.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2024.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.6.0)

# %% [markdown]
# ### Import Libraries

# %%
# import Librairies
import os
import pandas as pd
import numpy as  np
import json
import requests
import boto3
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from google.cloud import storage
from io import StringIO

# %% [markdown]
# ## Extract

# %%
url_list = ["https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2014Q1.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2014Q2.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2014Q3.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2014Q4.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2015Q1.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2015Q2.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2015Q3.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2015Q4.csv",
            "https://raw.githubusercontent.com/CityOfPhiladelphia/contracts/gh-pages/commodities/data/FY2016Q1.csv"]

# %%
df_raw_list = []

for url in url_list:
  df_raw = pd.read_csv(url, encoding='latin-1')
  df_raw_list.append(df_raw)
  print(df_raw.info())

print(len(df_raw_list))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             863 non-null    object
#  1   Contract_Number        863 non-null    object
#  2   Contract_Description   860 non-null    object
#  3   Start_Date             863 non-null    int64
#  4   End_Date               709 non-null    float64
#  5   Contract_Type          863 non-null    object
#  6   Vendor_Name            863 non-null    object
#  7   Department_Name        863 non-null    object
#  8   Contract_Amount        863 non-null    object
#  9   Total_Contract_Months  664 non-null    float64
#  10  Total_Transactions     669 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 74.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             885 non-null    object
#  1   Contract_Number        885 non-null    object
#  2   Contract_Description   882 non-null    object
#  3   Start_Date             885 non-null    int64
#  4   End_Date               722 non-null    float64
#  5   Contract_Type          885 non-null    object
#  6   Vendor_Name            885 non-null    object
#  7   Department_Name        885 non-null    object
#  8   Contract_Amount        885 non-null    object
#  9   Total_Contract_Months  681 non-null    float64
#  10  Total_Transactions     691 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 76.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             868 non-null    object
#  1   Contract_Number        868 non-null    object
#  2   Contract_Description   865 non-null    object
#  3   Start_Date             868 non-null    int64
#  4   End_Date               738 non-null    float64
#  5   Contract_Type          868 non-null    object
#  6   Vendor_Name            868 non-null    object
#  7   Department_Name        868 non-null    object
#  8   Contract_Amount        868 non-null    object
#  9   Total_Contract_Months  696 non-null    float64
#  10  Total_Transactions     652 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 74.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             859 non-null    object
#  1   Contract_Number        859 non-null    object
#  2   Contract_Description   857 non-null    object
#  3   Start_Date             859 non-null    int64
#  4   End_Date               729 non-null    float64
#  5   Contract_Type          859 non-null    object
#  6   Vendor_Name            859 non-null    object
#  7   Department_Name        859 non-null    object
#  8   Contract_Amount        859 non-null    object
#  9   Total_Contract_Months  695 non-null    float64
#  10  Total_Transactions     664 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 73.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             892 non-null    object
#  1   Contract_Number        893 non-null    object
#  2   Contract_Description   891 non-null    object
#  3   Start_Date             893 non-null    int64
#  4   End_Date               730 non-null    float64
#  5   Contract_Type          893 non-null    object
#  6   Vendor_Name            893 non-null    object
#  7   Department_Name        893 non-null    object
#  8   Contract_Amount        893 non-null    object
#  9   Total_Contract_Months  696 non-null    float64
#  10  Total_Transactions     702 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 76.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 907 non-null    object
#  1   Contract_Number            907 non-null    object
#  2   Contract_Description       905 non-null    object
#  3   Start_Date                 907 non-null    int64
#  4   End_Date                   740 non-null    float64
#  5   Contract_Type              907 non-null    object
#  6   Vendor_Name                907 non-null    object
#  7   Department_Name            907 non-null    object
#  8   Contract_Amount            907 non-null    object
#  9   Total_Contract_Months      709 non-null    float64
#  10  Remaining_Contract_Months  709 non-null    float64
#  11  Total_Transactions         670 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 85.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 831 non-null    object
#  1   Contract_Number            831 non-null    object
#  2   Contract_Description       830 non-null    object
#  3   Start_Date                 831 non-null    int64
#  4   End_Date                   668 non-null    float64
#  5   Contract_Type              831 non-null    object
#  6   Vendor_Name                831 non-null    object
#  7   Department_Name            831 non-null    object
#  8   Contract_Amount            831 non-null    object
#  9   Total_Contract_Months      641 non-null    float64
#  10  Remaining_Contract_Months  641 non-null    float64
#  11  Total_Transactions         593 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 78.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 822 non-null    object
#  1   Contract_Number            822 non-null    object
#  2   Contract_Description       821 non-null    object
#  3   Start_Date                 822 non-null    int64
#  4   End_Date                   664 non-null    float64
#  5   Contract_Type              822 non-null    object
#  6   Vendor_Name                822 non-null    object
#  7   Department_Name            822 non-null    object
#  8   Contract_Amount            822 non-null    object
#  9   Total_Contract_Months      635 non-null    float64
#  10  Remaining_Contract_Months  635 non-null    float64
#  11  Total_Transactions         633 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 77.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 840 non-null    object
#  1   Contract_Number            840 non-null    object
#  2   Contract_Description       838 non-null    object
#  3   Start_Date                 840 non-null    int64
#  4   End_Date                   665 non-null    float64
#  5   Contract_Type              840 non-null    object
#  6   Vendor_Name                840 non-null    object
#  7   Department_Name            840 non-null    object
#  8   Contract_Amount            840 non-null    object
#  9   Total_Contract_Months      629 non-null    float64
#  10  Remaining_Contract_Months  629 non-null    float64
#  11  Total_Transactions         615 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 78.9+ KB
# None
# 9

# %%
df_clean_list = []

for df_raw in df_raw_list:
  df_clean = df_raw.copy()
  # if 'Remaining_Contract_Months' in df_clean.columns:
  #   df_clean = df_clean.drop(columns=['Remaining_Contract_Months'])
  df_clean = df_clean.dropna(
      subset = ['End_Date'],
      ignore_index = True)
  print(df_clean.info())
  df_clean_list.append(df_clean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             709 non-null    object
#  1   Contract_Number        709 non-null    object
#  2   Contract_Description   706 non-null    object
#  3   Start_Date             709 non-null    int64
#  4   End_Date               709 non-null    float64
#  5   Contract_Type          709 non-null    object
#  6   Vendor_Name            709 non-null    object
#  7   Department_Name        709 non-null    object
#  8   Contract_Amount        709 non-null    object
#  9   Total_Contract_Months  664 non-null    float64
#  10  Total_Transactions     515 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 61.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             722 non-null    object
#  1   Contract_Number        722 non-null    object
#  2   Contract_Description   719 non-null    object
#  3   Start_Date             722 non-null    int64
#  4   End_Date               722 non-null    float64
#  5   Contract_Type          722 non-null    object
#  6   Vendor_Name            722 non-null    object
#  7   Department_Name        722 non-null    object
#  8   Contract_Amount        722 non-null    object
#  9   Total_Contract_Months  681 non-null    float64
#  10  Total_Transactions     529 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 62.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             738 non-null    object
#  1   Contract_Number        738 non-null    object
#  2   Contract_Description   735 non-null    object
#  3   Start_Date             738 non-null    int64
#  4   End_Date               738 non-null    float64
#  5   Contract_Type          738 non-null    object
#  6   Vendor_Name            738 non-null    object
#  7   Department_Name        738 non-null    object
#  8   Contract_Amount        738 non-null    object
#  9   Total_Contract_Months  696 non-null    float64
#  10  Total_Transactions     523 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 63.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             729 non-null    object
#  1   Contract_Number        729 non-null    object
#  2   Contract_Description   727 non-null    object
#  3   Start_Date             729 non-null    int64
#  4   End_Date               729 non-null    float64
#  5   Contract_Type          729 non-null    object
#  6   Vendor_Name            729 non-null    object
#  7   Department_Name        729 non-null    object
#  8   Contract_Amount        729 non-null    object
#  9   Total_Contract_Months  695 non-null    float64
#  10  Total_Transactions     536 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 62.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bid_Number             729 non-null    object
#  1   Contract_Number        730 non-null    object
#  2   Contract_Description   728 non-null    object
#  3   Start_Date             730 non-null    int64
#  4   End_Date               730 non-null    float64
#  5   Contract_Type          730 non-null    object
#  6   Vendor_Name            730 non-null    object
#  7   Department_Name        730 non-null    object
#  8   Contract_Amount        730 non-null    object
#  9   Total_Contract_Months  696 non-null    float64
#  10  Total_Transactions     543 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 62.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 740 non-null    object
#  1   Contract_Number            740 non-null    object
#  2   Contract_Description       738 non-null    object
#  3   Start_Date                 740 non-null    int64
#  4   End_Date                   740 non-null    float64
#  5   Contract_Type              740 non-null    object
#  6   Vendor_Name                740 non-null    object
#  7   Department_Name            740 non-null    object
#  8   Contract_Amount            740 non-null    object
#  9   Total_Contract_Months      709 non-null    float64
#  10  Remaining_Contract_Months  709 non-null    float64
#  11  Total_Transactions         503 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 69.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 668 non-null    object
#  1   Contract_Number            668 non-null    object
#  2   Contract_Description       667 non-null    object
#  3   Start_Date                 668 non-null    int64
#  4   End_Date                   668 non-null    float64
#  5   Contract_Type              668 non-null    object
#  6   Vendor_Name                668 non-null    object
#  7   Department_Name            668 non-null    object
#  8   Contract_Amount            668 non-null    object
#  9   Total_Contract_Months      641 non-null    float64
#  10  Remaining_Contract_Months  641 non-null    float64
#  11  Total_Transactions         430 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 62.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 664 non-null    object
#  1   Contract_Number            664 non-null    object
#  2   Contract_Description       663 non-null    object
#  3   Start_Date                 664 non-null    int64
#  4   End_Date                   664 non-null    float64
#  5   Contract_Type              664 non-null    object
#  6   Vendor_Name                664 non-null    object
#  7   Department_Name            664 non-null    object
#  8   Contract_Amount            664 non-null    object
#  9   Total_Contract_Months      635 non-null    float64
#  10  Remaining_Contract_Months  635 non-null    float64
#  11  Total_Transactions         475 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 62.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Bid_Number                 665 non-null    object
#  1   Contract_Number            665 non-null    object
#  2   Contract_Description       663 non-null    object
#  3   Start_Date                 665 non-null    int64
#  4   End_Date                   665 non-null    float64
#  5   Contract_Type              665 non-null    object
#  6   Vendor_Name                665 non-null    object
#  7   Department_Name            665 non-null    object
#  8   Contract_Amount            665 non-null    object
#  9   Total_Contract_Months      629 non-null    float64
#  10  Remaining_Contract_Months  629 non-null    float64
#  11  Total_Transactions         440 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 62.5+ KB
# None

# %% [markdown]
# ## Store to Staging

# %%
# Specify the path to your JSON configuration file
config_file_path = "config.json"

# Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
  config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = 'commodities-contracts'

# Generate blob names
blob_name_list = []
for url in url_list:
  blob_name = url[-12:]
  blob_name_list.append(blob_name)
print(blob_name_list)

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

for i in range(len(df_clean_list)):
  df = df_clean_list[i]
  blob_name = blob_name_list[i]

  # Convert DataFrame to CSV
  output = StringIO()
  df.to_csv(output, index=False)
  data = output.getvalue()
  output.close()

  # Get a blob client using the container name and blob name
  blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

  # Upload the CSV data
  blob_client.upload_blob(data, overwrite=True)

  print(f"Uploaded {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}.")
# Out:
# ['FY2014Q1.csv', 'FY2014Q2.csv', 'FY2014Q3.csv', 'FY2014Q4.csv', 'FY2015Q1.csv', 'FY2015Q2.csv', 'FY2015Q3.csv', 'FY2015Q4.csv', 'FY2016Q1.csv']
# Uploaded FY2014Q1.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2014Q2.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2014Q3.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2014Q4.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2015Q1.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2015Q2.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2015Q3.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2015Q4.csv to Azure Blob Storage in container commodities-contracts.
# Uploaded FY2016Q1.csv to Azure Blob Storage in container commodities-contracts.
